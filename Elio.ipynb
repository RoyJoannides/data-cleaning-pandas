# %%
import pandas as pd
url = 'https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'
pd.set_option('display.max_columns', None)
df = pd.read_excel(url)

# %% [markdown]
# # Duplicated values - None

# %%
print(df.duplicated().sum()) # checking for duplicates -> 0
# Out:
# 24

# %% [markdown]
# # Deleting columns that are not useful

# %%
df. drop(['href formula','Unnamed: 11','href', 'Case Number', 'Case Number.1',
       'original order', 'Unnamed: 21', 'Unnamed: 22'], axis=1,inplace=True)

# %%
df # state of dataframe
# Out:
#              Date    Year        Type    Country             State  \
# 0     14 Feb-2024  2024.0  Unprovoked      INDIA       Maharashtra
# 1     04-Feb-2024  2024.0    Provoked   TRINIDAD               NaN
# 2     29 Jan-2024  2024.0  Unprovoked  AUSTRALIA  New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked    BAHAMAS   Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked  AUSTRALIA   South Australia
# ...           ...     ...         ...        ...               ...
# 6960          NaN     NaN         NaN        NaN               NaN
# 6961          NaN     NaN         NaN        NaN               NaN
# 6962          NaN     NaN         NaN        NaN               NaN
# 6963          NaN     NaN         NaN        NaN               NaN
# 6964          NaN     NaN         NaN        NaN               NaN
#
#                               Location      Activity                 Name  \
# 0     Vaitarna River, Palghar District       Fishing  Vicky Suresh Govari
# 1                                  NaN  Spearfishing                 male
# 2         Elizabeth Bay, Sydney Harbor      Swimming       Lauren O'Neill
# 3               Paradise Island Resort      Swimming                 male
# 4              Walkers Beach, Elliston       Surfing         Murray Adams
# ...                                ...           ...                  ...
# 6960                               NaN           NaN                  NaN
# 6961                               NaN           NaN                  NaN
# 6962                               NaN           NaN                  NaN
# 6963                               NaN           NaN                  NaN
# 6964                               NaN           NaN                  NaN
#
#       Sex  Age                          Injury   Time             Species   \
# 0       M   32  Calf of lower left leg injured    NaN       Bull shark, 7'
# 1       M  NaN                 Shoulder bitten  06h30  Blacktip reef shark
# 2       F   29                Right leg bitten  20h00           Bull shark
# 3       M   10              Right leg injured   16h00                  NaN
# 4       M   64                      Leg bitten  13h00          White shark
# ...   ...  ...                             ...    ...                  ...
# 6960  NaN  NaN                             NaN    NaN                  NaN
# 6961  NaN  NaN                             NaN    NaN                  NaN
# 6962  NaN  NaN                             NaN    NaN                  NaN
# 6963  NaN  NaN                             NaN    NaN                  NaN
# 6964  NaN  NaN                             NaN    NaN                  NaN
#
#                                Source  pdf
# 0           Times of India, 2/14/2024  NaN
# 1        Trinidad Guardian, 2/11/2014  NaN
# 2               Nine News, 12/31/2024  NaN
# 3     Caribbean Loop News, 1/15;2024   NaN
# 4                     A. Currie, GSAF  NaN
# ...                               ...  ...
# 6960                              NaN  NaN
# 6961                              NaN  NaN
# 6962                              NaN  NaN
# 6963                              NaN  NaN
# 6964                              NaN  NaN
#
# [6965 rows x 15 columns]

# %% [markdown]
# # Deleting null values

# %%
print(df.isnull().sum()) # checking how many null values to each column
# Out:
# Date          25
# Year          27
# Type          43
# Country       75
# State        507
# Location     590
# Activity     610
# Name         244
# Sex          604
# Age         3018
# Injury        60
# Time        3550
# Species     3157
# Source        44
# pdf          166
# dtype: int64

# %%
print(f"The number of rows before the dropna are: {df.shape[0]}.") # 6965 rows
# Out:
# The number of rows before the dropna are: 6965.

# %%
rows_with_all_null = df[df.isnull().all(axis=1)]
print(f"{rows_with_all_null.shape[0]} rows with all null values were found:")
print(rows_with_all_null)
# it found 25 rows
# Out:
# 25 rows with all null values were found:
#      Date  Year Type Country State Location Activity Name  Sex  Age Injury  \
# 6940  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6941  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6942  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6943  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6944  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6945  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6946  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6947  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6948  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6949  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6950  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6951  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6952  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6953  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6954  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6955  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6956  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6957  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6958  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6959  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6960  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6961  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6962  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6963  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
# 6964  NaN   NaN  NaN     NaN   NaN      NaN      NaN  NaN  NaN  NaN    NaN
#
#      Time Species  Source  pdf
# 6940  NaN      NaN    NaN  NaN
# 6941  NaN      NaN    NaN  NaN
# 6942  NaN      NaN    NaN  NaN
# 6943  NaN      NaN    NaN  NaN
# 6944  NaN      NaN    NaN  NaN
# 6945  NaN      NaN    NaN  NaN
# 6946  NaN      NaN    NaN  NaN
# 6947  NaN      NaN    NaN  NaN
# 6948  NaN      NaN    NaN  NaN
# 6949  NaN      NaN    NaN  NaN
# 6950  NaN      NaN    NaN  NaN
# 6951  NaN      NaN    NaN  NaN
# 6952  NaN      NaN    NaN  NaN
# 6953  NaN      NaN    NaN  NaN
# 6954  NaN      NaN    NaN  NaN
# 6955  NaN      NaN    NaN  NaN
# 6956  NaN      NaN    NaN  NaN
# 6957  NaN      NaN    NaN  NaN
# 6958  NaN      NaN    NaN  NaN
# 6959  NaN      NaN    NaN  NaN
# 6960  NaN      NaN    NaN  NaN
# 6961  NaN      NaN    NaN  NaN
# 6962  NaN      NaN    NaN  NaN
# 6963  NaN      NaN    NaN  NaN
# 6964  NaN      NaN    NaN  NaN

# %%
df.dropna(how='all', inplace=True)

# %%
print(f"The number of rows after the dropna are: {df.shape[0]}.") # 6940 rows -> difference: 25, correct
# Out:
# The number of rows after the dropna are: 6940.

# %% [markdown]
# # Date

# %% [markdown]
# ##### -> Date needs to be cleaned!

# %%
df["Date"]
# Out:
# 0       14 Feb-2024
# 1       04-Feb-2024
# 2       29 Jan-2024
# 3       15 Jan-2024
# 4       09-Jan-2024
#            ...
# 6935    Before 1903
# 6936    Before 1903
# 6937      1900-1905
# 6938      1883-1889
# 6939      1845-1853
# Name: Date, Length: 6940, dtype: object

# %%
df["Date"].head(30) # many different formats for date
# Out:
# 0              14 Feb-2024
# 1              04-Feb-2024
# 2              29 Jan-2024
# 3              15 Jan-2024
# 4              09-Jan-2024
# 5              05-Jan-2024
# 6              30 Dec-2023
# 7              29 Dec-2023
# 8              28 Dec-2023
# 9              25 Dec-2023
# 10             24-Dec-2023
# 11             18 Dec-2023
# 12            14  Dec-2023
# 13            14  Dec-2023
# 14             08 Dec-2023
# 15             04 Dec-2023
# 16             02 Dec-2023
# 17             30 Nov-2023
# 18             21 Nov-2023
# 19             10 Nov-2023
# 20             05 Nov-2023
# 21             03 Nov-2023
# 22             02 Nov-2023
# 23    Reported 02 Nov-2023
# 24             31 Oct-2023
# 25             25 Oct 2023
# 26             23 Oct-2023
# 27             21 Oct-2023
# 28             20 Oct 2023
# 29             15 Oct 2023
# Name: Date, dtype: object

# %% [markdown]
# ##### Month check

# %%
df['Month'] = df['Date'].str.replace("Between", " ").str.replace("Fall", " ").str.replace("fall", " ").str.replace("summer", " ").str.replace("Early", " ").str.replace("Reported", " ").str.replace("Before", " ").str.replace("Summer", " ").str.replace("Late", " ").str.extract(r'([A-Za-z]{3})')

# %%
# I ignored Reported, cause I assume that it doesn't make much difference
# usually incidents will be reported max a few days after, not months after

# %%
'''
a = df[df["Month"] == "Rep"]
a # here I see that the Rep is actually for reported, there were 500+ entries with Reported
'''
# Out:
# '\na = df[df["Month"] == "Rep"]\na # here I see that the Rep is actually for reported, there were 500+ entries with Reported\n'

# %%
df['Month'].value_counts() # July and August are the most active months
# Out:
# Month
# Jul    771
# Aug    661
# Sep    606
# Jan    561
# Jun    545
# Oct    498
# Apr    492
# Dec    489
# Mar    454
# Nov    449
# May    448
# Feb    415
# dat     26
# Mid      5
# Cir      5
# Win      2
# Wor      2
# sam      2
# Som      2
# Dur      2
# Rep      2
# Let      1
# Sai      1
# the      1
# Nox      1
# Aft      1
# Pri      1
# mid      1
# Ann      1
# and      1
# soo      1
# hav      1
# Woi      1
# Las      1
# few      1
# Name: count, dtype: int64

# %% [markdown]
# # df - DISPLAY

# %%
df
# Out:
#              Date    Year        Type             Country              State  \
# 0     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# 1     04-Feb-2024  2024.0    Provoked            TRINIDAD                NaN
# 2     29 Jan-2024  2024.0  Unprovoked           AUSTRALIA   New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked             BAHAMAS    Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked           AUSTRALIA    South Australia
# ...           ...     ...         ...                 ...                ...
# 6935  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6936  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6937    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6938    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6939    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0        Vaitarna River, Palghar District       Fishing
# 1                                     NaN  Spearfishing
# 2            Elizabeth Bay, Sydney Harbor      Swimming
# 3                  Paradise Island Resort      Swimming
# 4                 Walkers Beach, Elliston       Surfing
# ...                                   ...           ...
# 6935                          Roebuck Bay        Diving
# 6936                                  NaN  Pearl diving
# 6937                       Ocracoke Inlet      Swimming
# 6938                 Panama Bay 8ºN, 79ºW           NaN
# 6939  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  \
# 0       Vicky Suresh Govari   M   32
# 1                      male   M  NaN
# 2            Lauren O'Neill   F   29
# 3                      male   M   10
# 4              Murray Adams   M   64
# ...                     ...  ..  ...
# 6935                   male   M  NaN
# 6936                  Ahmun   M  NaN
# 6937  Coast Guard personnel   M  NaN
# 6938        Jules Patterson   M  NaN
# 6939                   male   M   15
#
#                                                  Injury   Time  \
# 0                        Calf of lower left leg injured    NaN
# 1                                       Shoulder bitten  06h30
# 2                                      Right leg bitten  20h00
# 3                                    Right leg injured   16h00
# 4                                            Leg bitten  13h00
# ...                                                 ...    ...
# 6935                                              FATAL    NaN
# 6936                                              FATAL    NaN
# 6937                                              FATAL    NaN
# 6938                                              FATAL    NaN
# 6939  FATAL. "Shark bit him in half, carrying away t...    NaN
#
#                  Species                                  Source  \
# 0          Bull shark, 7'              Times of India, 2/14/2024
# 1     Blacktip reef shark           Trinidad Guardian, 2/11/2014
# 2              Bull shark                  Nine News, 12/31/2024
# 3                     NaN        Caribbean Loop News, 1/15;2024
# 4             White shark                        A. Currie, GSAF
# ...                   ...                                    ...
# 6935                  NaN       H. Taunton; N. Bartlett,  p. 234
# 6936                  NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6937                  NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6938                  NaN                    The Sun, 10/20/1938
# 6939                  NaN                             S.W. Baker
#
#                                  pdf Month
# 0                                NaN   Feb
# 1                                NaN   Feb
# 2                                NaN   Jan
# 3                                NaN   Jan
# 4                                NaN   Jan
# ...                              ...   ...
# 6935          ND-0005-RoebuckBay.pdf   NaN
# 6936               ND-0004-Ahmun.pdf   NaN
# 6937  ND-0003-Ocracoke_1900-1905.pdf   NaN
# 6938      ND-0002-JulesPatterson.pdf   NaN
# 6939              ND-0001-Ceylon.pdf   NaN
#
# [6940 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Time', 'Species ', 'Source', 'pdf',
#        'Month'],
#       dtype='object')

# %%
df.isna().sum(axis=1)
# Out:
# 0       2
# 1       4
# 2       1
# 3       2
# 4       1
#        ..
# 6935    4
# 6936    5
# 6937    4
# 6938    6
# 6939    3
# Length: 6940, dtype: int64

# %%
#Lose PDF column
#Lose State
#Handle all the null
#Time and age replace by avg
#Delete rows with a majority of nulls
#Check for duplicates
#Format Data

# %%
df.isna().sum()
# Out:
# Date           0
# Year           2
# Type          18
# Country       50
# State        482
# Location     565
# Activity     585
# Name         219
# Sex          579
# Age         2993
# Injury        35
# Time        3525
# Species     3132
# Source        19
# pdf          141
# Month        489
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
#1. Lose PDF, source, location columns✅
#2. Handle all the null
#Time and age replace by avg✅
#Delete rows with a majority of nulls
#4.Check for duplicates
#3.Format Data

# %%
#1. Lose PDF, source, location columns

columns_to_drop = ['Location', 'pdf', 'Source']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
#2. Handle all the null
df.isnull().sum()
df.isnull().any()
df.isnull().sum(axis=1)
df.dropna(how='all', inplace=True) #drop all rows with all of the 13 values null (-24 rows)

# Convert 'Age' column to numeric type to ensure all values are numeric
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
# Replace null values in the 'Age' column with the average age
df['Age'].fillna(df['Age'].mean(), inplace=True)

df['Time'] = pd.to_numeric(df['Time'], errors='coerce')
df['Time'].fillna(df['Time'].mean(), inplace=True)
df.dropna(subset=['Country'], inplace=True)
#df.dropna(thresh=10)#with 13 we have 3054 rows, 12 >> 5773, 11 >> 6555

# %%
df.isnull().sum()
# Out:
# Date           0
# Year           2
# Type          18
# Country        0
# State        447
# Activity     578
# Name         215
# Sex          575
# Age            0
# Injury        33
# Time           0
# Species     3094
# Month        478
# dtype: int64

# %%
df
# Out:
#              Date    Year        Type             Country              State  \
# 0     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# 1     04-Feb-2024  2024.0    Provoked            TRINIDAD                NaN
# 2     29 Jan-2024  2024.0  Unprovoked           AUSTRALIA   New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked             BAHAMAS    Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked           AUSTRALIA    South Australia
# ...           ...     ...         ...                 ...                ...
# 6935  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6936  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6937    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6938    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6939    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#           Activity                   Name Sex        Age  \
# 0          Fishing    Vicky Suresh Govari   M  32.000000
# 1     Spearfishing                   male   M  28.046658
# 2         Swimming         Lauren O'Neill   F  29.000000
# 3         Swimming                   male   M  10.000000
# 4          Surfing           Murray Adams   M  64.000000
# ...            ...                    ...  ..        ...
# 6935        Diving                   male   M  28.046658
# 6936  Pearl diving                  Ahmun   M  28.046658
# 6937      Swimming  Coast Guard personnel   M  28.046658
# 6938           NaN        Jules Patterson   M  28.046658
# 6939      Swimming                   male   M  15.000000
#
#                                                  Injury         Time  \
# 0                        Calf of lower left leg injured  1249.285714
# 1                                       Shoulder bitten  1249.285714
# 2                                      Right leg bitten  1249.285714
# 3                                    Right leg injured   1249.285714
# 4                                            Leg bitten  1249.285714
# ...                                                 ...          ...
# 6935                                              FATAL  1249.285714
# 6936                                              FATAL  1249.285714
# 6937                                              FATAL  1249.285714
# 6938                                              FATAL  1249.285714
# 6939  FATAL. "Shark bit him in half, carrying away t...  1249.285714
#
#                  Species  Month
# 0          Bull shark, 7'   Feb
# 1     Blacktip reef shark   Feb
# 2              Bull shark   Jan
# 3                     NaN   Jan
# 4             White shark   Jan
# ...                   ...   ...
# 6935                  NaN   NaN
# 6936                  NaN   NaN
# 6937                  NaN   NaN
# 6938                  NaN   NaN
# 6939                  NaN   NaN
#
# [6890 rows x 13 columns]
